# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# API Requests
from pprint import pprint
import requests
import json

# Data Viz
import hvplot.pandas
import matplotlib.pyplot as plt
import seaborn as sns

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b360b274-d591-4850-93d4-1ccaf8636ace" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"df4a6a27-d661-4597-84a7-36a65b6fda0f":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"10205e1a6f7f4f4698f553aeb31d654b","client_comm_id":"1628904687604d939901ddeb13adaa87"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"df4a6a27-d661-4597-84a7-36a65b6fda0f","roots":{"p1002":"b360b274-d591-4850-93d4-1ccaf8636ace"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         Puerto Ayora  -0.7393  -90.3518     72.46        80          73
# 1        Fort St. John  56.2499 -120.8529     17.49        93          75
# 2                Tiksi  71.6872  128.8694     -9.71       100          50
# 3              Stanley  54.8680   -1.6985     36.18        86          20
# 4          Egilsstadir  65.2653  -14.3948     13.91        67           0
#
#          Wind Speed Country        Date  Pressure
# City_ID
# 0             10.42      EC  1733169497      1011
# 1              4.61      CA  1733169582      1009
# 2              5.46      RU  1733169434      1022
# 3              6.91      GB  1733169436      1019
# 4              6.91      IS  1733169586      1019

# %%
# Date Cleaning w/dates
city_data_df["Date"] = pd.to_datetime(city_data_df.Date * 1e9)
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         Puerto Ayora  -0.7393  -90.3518     72.46        80          73
# 1        Fort St. John  56.2499 -120.8529     17.49        93          75
# 2                Tiksi  71.6872  128.8694     -9.71       100          50
# 3              Stanley  54.8680   -1.6985     36.18        86          20
# 4          Egilsstadir  65.2653  -14.3948     13.91        67           0
#
#          Wind Speed Country                Date  Pressure
# City_ID
# 0             10.42      EC 2024-12-02 19:58:17      1011
# 1              4.61      CA 2024-12-02 19:59:42      1009
# 2              5.46      RU 2024-12-02 19:57:14      1022
# 3              6.91      GB 2024-12-02 19:57:16      1019
# 4              6.91      IS 2024-12-02 19:59:46      1019

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 586 entries, 0 to 585
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        586 non-null    object
#  1   Lat         586 non-null    float64
#  2   Lng         586 non-null    float64
#  3   Max Temp    586 non-null    float64
#  4   Humidity    586 non-null    int64
#  5   Cloudiness  586 non-null    int64
#  6   Wind Speed  586 non-null    float64
#  7   Country     581 non-null    object
#  8   Date        586 non-null    datetime64[ns]
#  9   Pressure    586 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(3), object(2)
# memory usage: 50.4+ KB

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    color = "City",
    hover_cols=["City", "Country", "Max Temp"]
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Country,Max Temp)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
min_temp = 70
max_temp = 80
max_wind = 10

# Drop any rows with null values
ideal_w = city_data_df.dropna()

mask = (ideal_w["Max Temp"] >= min_temp) & (ideal_w["Max Temp"] < max_temp) & (ideal_w["Wind Speed"] < max_wind)
ideal_w = ideal_w.loc[mask].reset_index(drop=True)

# Display sample data
ideal_w
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Kourou   5.1552  -52.6478     77.95        92          99
# 1   Wailua Homesteads  22.0669 -159.3780     77.79        80          75
# 2               Dawei  14.0833   98.2000     71.37        79          56
# 3             Jwaneng -24.6004   24.7303     79.50        18          53
# 4      Cabo San Lucas  22.8909 -109.9124     77.76        61           4
# ..                ...      ...       ...       ...       ...         ...
# 88          Manokwari  -0.8667  134.0833     78.28        84          97
# 89          Gorontalo   0.5412  123.0595     75.25        90          99
# 90       Capitán Bado -23.2667  -55.5333     77.88        84          50
# 91            Biltine  14.5333   20.9167     72.37        15           6
# 92    Ribeirão Bonito -22.0667  -48.1761     76.60        86         100
#
#     Wind Speed Country                Date  Pressure
# 0         9.01      GF 2024-12-02 19:59:16      1010
# 1         9.22      US 2024-12-02 19:58:07      1017
# 2         3.60      MM 2024-12-02 20:00:33      1009
# 3         4.90      BW 2024-12-02 20:00:34      1007
# 4         4.00      MX 2024-12-02 19:56:04      1014
# ..         ...     ...                 ...       ...
# 88        3.27      ID 2024-12-02 20:11:16      1007
# 89        3.36      ID 2024-12-02 20:09:02      1007
# 90        9.44      PY 2024-12-02 20:11:28      1004
# 91        8.93      TD 2024-12-02 20:11:29      1014
# 92        6.20      BR 2024-12-02 20:11:32      1008
#
# [93 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
hotel_rows = []

for index, row in ideal_w.iterrows():
    # from the Weather CSV
    city = row["City"]
    country = row["Country"]
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Set the parameters for the type of place
    categories = "accommodation.hotel"
    radius = 10000 # 10km
    
    # Set the parameters for the type of search
    filters = f"circle:{longitude},{latitude},{radius}"
    bias = f"proximity:{longitude},{latitude}"
    limit = 5
    
    # set up a parameters dictionary
    params = {
        "categories":categories,
        "limit":limit,
        "filter":filters,
        "bias":bias,
        "apiKey":geoapify_key    
    }
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Run request
    try:
        response = requests.get(base_url, params=params)
        # print(response.status_code)
        data = response.json()
        
        # Print the results
        results = data.get("features", [])
        
        # Resiliency/Error Handling
        if len(results) > 0:
            place = results[0]
    
            # normalize data
            address = place.get("properties", {}).get("formatted")
            name = place.get("properties", {}).get("name")
            distance = place.get("properties", {}).get("distance")
            elev = place.get("properties", {}).get("ele")
            website = place.get("properties", {}).get("website")
        
            # return object
            hotel_row = {
                "city": city,
                "country": country,
                "latitude": latitude,
                "longitude": longitude,
                "address": address,
                "name": name,
                "distance": distance
            }
        else:
            hotel_row = {
                "city": city,
                "country": country,
                "latitude": latitude,
                "longitude": longitude,
                "address": None,
                "name": None,
                "distance": None
            }
    except Exception as e:
        print(e)
        hotel_row = {
                "city": city,
                "country": country,
                "latitude": latitude,
                "longitude": longitude,
                "address": None,
                "name": None,
                "distance": None
            }

    # append to hotel list
    hotel_rows.append(hotel_row)

# %%
hotel_rows
# Out:
# [{'city': 'Kourou',
#   'country': 'GF',
#   'latitude': 5.1552,
#   'longitude': -52.6478,
#   'address': 'SCI Horizon, 54 Rue du Docteur Hervé Floch, 97310 Kourou, France',
#   'name': 'SCI Horizon',
#   'distance': 299},
#  {'city': 'Wailua Homesteads',
#   'country': 'US',
#   'latitude': 22.0669,
#   'longitude': -159.378,
#   'address': 'Hilton Garden Inn Kauai Wailua Bay, Kuhio Highway, Kauaʻi County, HI 96746, United States of America',
#   'name': 'Hilton Garden Inn Kauai Wailua Bay',
#   'distance': 4923},
#  {'city': 'Dawei',
#   'country': 'MM',
#   'latitude': 14.0833,
#   'longitude': 98.2,
#   'address': 'Royal Dawei Hotel, Say Yone Road, Dawei, 60101, Myanmar',
#   'name': 'Royal Dawei ဟိုတယ်',
#   'distance': 784},
#  {'city': 'Jwaneng',
#   'country': 'BW',
#   'latitude': -24.6004,
#   'longitude': 24.7303,
#   'address': 'Mokala Lodge & Teemane Casino, Kgorwe Avenue, Jwaneng, Botswana',
#   'name': 'Mokala Lodge & Teemane Casino',
#   'distance': 187},
#  {'city': 'Cabo San Lucas',
#   'country': 'MX',
#   'latitude': 22.8909,
#   'longitude': -109.9124,
#   'address': 'Comfort Rooms, Calle Revolución de 1910, Juárez, 23469 Cabo San Lucas, BCS, Mexico',
#   'name': 'Comfort Rooms',
#   'distance': 65},
#  {'city': 'Nieuw Amsterdam',
#   'country': 'SR',
#   'latitude': 5.8833,
#   'longitude': -55.0833,
#   'address': 'Leonsberg Lodge, Anton Dragtenweg, Noord, Suriname',
#   'name': 'Leonsberg Lodge',
#   'distance': 2478},
#  {'city': 'Owando',
#   'country': 'CG',
#   'latitude': -0.4819,
#   'longitude': 15.8999,
#   'address': "Hotel de l'Eglise, RN 2, Owando, Congo-Brazzaville",
#   'name': "Hotel de l'Eglise",
#   'distance': 299},
#  {'city': 'Koné',
#   'country': 'NC',
#   'latitude': -21.0595,
#   'longitude': 164.8658,
#   'address': 'Pacifik Appartels, 213 Rue Auguste Henriot, 98859 Koné, France',
#   'name': 'Pacifik Appartels',
#   'distance': 411},
#  {'city': 'Sinabang',
#   'country': 'ID',
#   'latitude': 2.4803,
#   'longitude': 96.3801,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Gordonvale',
#   'country': 'AU',
#   'latitude': -17.0936,
#   'longitude': 145.7842,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Al Muwayh',
#   'country': 'SA',
#   'latitude': 22.4333,
#   'longitude': 41.7583,
#   'address': 'فندق ومطعم الموية, Makkah Al-Mukarramah Road, Al Muwayh, Saudi Arabia',
#   'name': 'فندق ومطعم الموية',
#   'distance': 611},
#  {'city': 'Boyolangu',
#   'country': 'ID',
#   'latitude': -8.1181,
#   'longitude': 111.8935,
#   'address': 'Crown Victoria, Jalan Supriyadi, Tulungagung 66218, East Java, Indonesia',
#   'name': 'Crown Victoria',
#   'distance': 5062},
#  {'city': 'Tabou',
#   'country': 'CI',
#   'latitude': 4.423,
#   'longitude': -7.3528,
#   'address': "hôtel le rochet, A7, Tabou, Côte d'Ivoire",
#   'name': 'hôtel le rochet',
#   'distance': 722},
#  {'city': 'Kapaa',
#   'country': 'US',
#   'latitude': 22.0752,
#   'longitude': -159.319,
#   'address': 'Pono Kai Resort, Pono Kai Street, Kapaa, HI 96746, United States of America',
#   'name': 'Pono Kai Resort',
#   'distance': 157},
#  {'city': 'Yangon',
#   'country': 'MM',
#   'latitude': 16.8053,
#   'longitude': 96.1561,
#   'address': 'Academy, Shwe Gone Dine Road, Yangon, 11201, Myanmar',
#   'name': 'Academy',
#   'distance': 122},
#  {'city': 'Marabu',
#   'country': 'MY',
#   'latitude': 4.4148,
#   'longitude': 114.0089,
#   'address': 'One Times One Inn, 3533 Miri–Pujut Road, Krokop, 98000 Miri, Sarawak, Malaysia',
#   'name': 'One Times One Inn',
#   'distance': 244},
#  {'city': 'Simanggang',
#   'country': 'MY',
#   'latitude': 1.2472,
#   'longitude': 111.4528,
#   'address': 'Seri Simanggang Hotel, Jalan Abang Aing, 95000 Simanggang, Sarawak, Malaysia',
#   'name': 'Seri Simanggang Hotel',
#   'distance': 1320},
#  {'city': 'Toliara',
#   'country': 'MG',
#   'latitude': -23.35,
#   'longitude': 43.6667,
#   'address': 'Ambary, Rue Sacré Cœur, Tranombarotra, 569 Toliara, Madagascar',
#   'name': 'Ambary',
#   'distance': 104},
#  {'city': 'Pisco',
#   'country': 'PE',
#   'latitude': -13.7,
#   'longitude': -76.2167,
#   'address': 'La Portada, Calle Alipio Ponce Vasques, Pisco 11601, Peru',
#   'name': 'La Portada',
#   'distance': 1504},
#  {'city': 'Haiku-Pauwela',
#   'country': 'US',
#   'latitude': 20.9219,
#   'longitude': -156.3051,
#   'address': "Inn At Mama's Fish House, 799 Poho Place, Paia, HI 96779, United States of America",
#   'name': "Inn At Mama's Fish House",
#   'distance': 6460},
#  {'city': 'Angoche',
#   'country': 'MZ',
#   'latitude': -16.2325,
#   'longitude': 39.9086,
#   'address': 'Hotel Quirimbas, Rua de Parapato, Angoche, Mozambique',
#   'name': 'Hotel Quirimbas',
#   'distance': 304},
#  {'city': 'Alice Springs',
#   'country': 'AU',
#   'latitude': -23.7,
#   'longitude': 133.8833,
#   'address': 'Aurora Alice Springs, 11 Leichhardt Terrace, Alice Springs 4992, Australia',
#   'name': 'Aurora Alice Springs',
#   'distance': 48},
#  {'city': 'Avarua',
#   'country': 'CK',
#   'latitude': -21.2078,
#   'longitude': -159.775,
#   'address': 'Paradise Inn, Ara Tapu, Avarua, Cook Islands',
#   'name': 'Paradise Inn',
#   'distance': 610},
#  {'city': 'Quelimane',
#   'country': 'MZ',
#   'latitude': -17.8786,
#   'longitude': 36.8883,
#   'address': 'Mabassa, Rua Francisco Samuel Magaia, 2400 Quelimane, Mozambique',
#   'name': 'Mabassa',
#   'distance': 202},
#  {'city': 'Kabo',
#   'country': 'CF',
#   'latitude': 7.6994,
#   'longitude': 18.629,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Port Moresby',
#   'country': 'PG',
#   'latitude': -9.4431,
#   'longitude': 147.1797,
#   'address': 'The Sanctuary Hotel and Spa, Waigani Drive, Port Moresby 121 National Capital District, Papua New Guinea',
#   'name': 'The Sanctuary Hotel and Spa',
#   'distance': 16},
#  {'city': 'Acapulco de Juárez',
#   'country': 'MX',
#   'latitude': 16.8634,
#   'longitude': -99.8901,
#   'address': 'Hotel del Valle, Avenida Licenciado Manuel Gómez Morín, 39300 Acapulco, GRO, Mexico',
#   'name': 'Hotel del Valle',
#   'distance': 691},
#  {'city': 'Bougouni',
#   'country': 'ML',
#   'latitude': 11.417,
#   'longitude': -7.479,
#   'address': 'Hotel Piemont, RN8, Foulaboula, Mali',
#   'name': 'Hotel Piemont',
#   'distance': 1290},
#  {'city': 'Jayapura',
#   'country': 'ID',
#   'latitude': -2.5333,
#   'longitude': 140.7,
#   'address': 'Hotel Jasmine Jayapura, Jalan Percetakan 8, Imbi, Jayapura 99111, Papua, Indonesia',
#   'name': 'Hotel Jasmine Jayapura',
#   'distance': 930},
#  {'city': 'Tibati',
#   'country': 'CM',
#   'latitude': 6.4667,
#   'longitude': 12.6333,
#   'address': 'Hôtel Calypso Annexe, Tibati-Ngaoundal, Tibati, Cameroon',
#   'name': 'Hôtel Calypso Annexe',
#   'distance': 1211},
#  {'city': 'Tobelo',
#   'country': 'ID',
#   'latitude': 1.7284,
#   'longitude': 128.0095,
#   'address': 'JJ Guesthouse, Jalan Mumulati, Tobelo, North Maluku, Indonesia',
#   'name': 'JJ Guesthouse',
#   'distance': 812},
#  {'city': 'Nadi',
#   'country': 'FJ',
#   'latitude': -17.8,
#   'longitude': 177.4167,
#   'address': 'President Hotel, 8 Andrews Road, Nadi, Fiji',
#   'name': 'President Hotel',
#   'distance': 28},
#  {'city': 'Sumbawa Besar',
#   'country': 'ID',
#   'latitude': -8.5,
#   'longitude': 117.4333,
#   'address': 'Hotel Mekarsari, Jalan Hasanuddin, Sumbawa Besar, West Nusa Tenggara, Indonesia',
#   'name': 'Hotel Mekarsari',
#   'distance': 1297},
#  {'city': 'Banda Aceh',
#   'country': 'ID',
#   'latitude': 5.5577,
#   'longitude': 95.3222,
#   'address': 'Hotel 61, Jalan Sri Ratu Safiatuddin, Peunayong, Banda Aceh 23241, Aceh, Indonesia',
#   'name': 'Hotel 61',
#   'distance': 85},
#  {'city': 'Nelson Bay',
#   'country': 'AU',
#   'latitude': -32.7167,
#   'longitude': 152.15,
#   'address': 'Government Road, Nelson Bay NSW 2315, Australia',
#   'name': None,
#   'distance': 707},
#  {'city': 'Chimoio',
#   'country': 'MZ',
#   'latitude': -19.1164,
#   'longitude': 33.4833,
#   'address': 'Rua do Hotel Amirana, Cidade de Chimoio, Mozambique',
#   'name': 'Hotel Amirana',
#   'distance': 334},
#  {'city': 'Guerrero Negro',
#   'country': 'MX',
#   'latitude': 27.9769,
#   'longitude': -114.0611,
#   'address': 'Plaza sal paraiso, Calle Sergio Noyola N., 23940 Guerrero Negro, BCS, Mexico',
#   'name': 'Plaza sal paraiso',
#   'distance': 1649},
#  {'city': 'Wewak',
#   'country': 'PG',
#   'latitude': -3.5534,
#   'longitude': 143.6268,
#   'address': 'Boutique Hotel 2, Memorial Drive, Wewak 531 East Sepik, Papua New Guinea',
#   'name': 'Boutique Hotel 2',
#   'distance': 248},
#  {'city': 'Dubai',
#   'country': 'AE',
#   'latitude': 25.2582,
#   'longitude': 55.3047,
#   'address': 'Holiday Inn Bur Dubai - Embassy District, 20th Street, Al Hamriya, Dubai, Bur Dubai, United Arab Emirates',
#   'name': 'Holiday Inn Bur Dubai - Embassy District',
#   'distance': 69},
#  {'city': 'Petauke',
#   'country': 'ZM',
#   'latitude': -14.2426,
#   'longitude': 31.3253,
#   'address': 'Chimwemwe Lodge, D138, Petauke, Zambia',
#   'name': 'Chimwemwe Lodge',
#   'distance': 5888},
#  {'city': 'Goundam',
#   'country': 'ML',
#   'latitude': 16.4145,
#   'longitude': -3.6708,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Las Lomitas',
#   'country': 'AR',
#   'latitude': -24.7096,
#   'longitude': -60.593,
#   'address': 'Hotel Lomitas, General Güemes 570, Barrio Las Violetas, 3630 Las Lomitas, Argentina',
#   'name': 'Hotel Lomitas',
#   'distance': 203},
#  {'city': 'Alotau',
#   'country': 'PG',
#   'latitude': -10.3069,
#   'longitude': 150.4462,
#   'address': 'Alotau International Hotel, Charles Abel Highway, Alotau Milne Bay, Papua New Guinea',
#   'name': 'Alotau International Hotel',
#   'distance': 267},
#  {'city': 'Moranbah',
#   'country': 'AU',
#   'latitude': -22.0016,
#   'longitude': 148.0466,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Sittwe',
#   'country': 'MM',
#   'latitude': 20.15,
#   'longitude': 92.9,
#   'address': 'Yuzana Aung Motel 1, Main Road, Sittwe Township, Myanmar',
#   'name': 'Yuzana Aung Motel 1',
#   'distance': 414},
#  {'city': 'Rancho Palos Verdes',
#   'country': 'US',
#   'latitude': 33.7445,
#   'longitude': -118.387,
#   'address': 'Bluff Top Trail, Rancho Palos Verdes, CA 90275, United States of America',
#   'name': None,
#   'distance': 1360},
#  {'city': 'Wau',
#   'country': 'SS',
#   'latitude': 7.7029,
#   'longitude': 27.9953,
#   'address': 'Safari Park Hotel, Wau, Wau - Raja, Wau, South Sudan',
#   'name': 'Safari Park Hotel',
#   'distance': 1291},
#  {'city': 'Auki',
#   'country': 'SB',
#   'latitude': -8.7676,
#   'longitude': 160.7034,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Luanda',
#   'country': 'AO',
#   'latitude': -8.8368,
#   'longitude': 13.2343,
#   'address': 'Hotel Forum, Travessa Ho Chi Mimh, Luanda, Angola',
#   'name': 'Hotel Forum',
#   'distance': 93},
#  {'city': 'Cepu',
#   'country': 'ID',
#   'latitude': -7.1475,
#   'longitude': 111.5906,
#   'address': 'Hotel Allium, Jalan By Pass Cepu, Cepu, Blora 58312, Central Java, Indonesia',
#   'name': 'Hotel Allium',
#   'distance': 1432},
#  {'city': 'Meulaboh',
#   'country': 'ID',
#   'latitude': 4.1363,
#   'longitude': 96.1285,
#   'address': 'Hotel Meuligou, Jalan Singgah Mata II, Meulaboh, Aceh, Indonesia',
#   'name': 'Hotel Meuligou',
#   'distance': 889},
#  {'city': 'Song Cau',
#   'country': 'VN',
#   'latitude': 13.45,
#   'longitude': 109.2167,
#   'address': 'La Donna Hotel, Lý Thường Kiệt, Song Cau, Phú Yên Province, Vietnam',
#   'name': 'La Donna',
#   'distance': 1427},
#  {'city': 'Al Ghayzah',
#   'country': 'YE',
#   'latitude': 16.2079,
#   'longitude': 52.176,
#   'address': 'فندق تاج العرب, Airport Street, Al Ghaydah, Yemen',
#   'name': 'فندق تاج العرب',
#   'distance': 273},
#  {'city': 'Sawa Sawa',
#   'country': 'KE',
#   'latitude': -4.4717,
#   'longitude': 39.4846,
#   'address': 'Mbuyu Beach Bungalows, Ukunda-Ramisi Road, Ramisi ward, Kenya',
#   'name': 'Mbuyu Beach Bungalows',
#   'distance': 605},
#  {'city': 'Kaga-Bandoro',
#   'country': 'CF',
#   'latitude': 6.9896,
#   'longitude': 19.1874,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Pandan',
#   'country': 'PH',
#   'latitude': 14.0453,
#   'longitude': 124.1694,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'City of Balikpapan',
#   'country': 'ID',
#   'latitude': -1.242,
#   'longitude': 116.8942,
#   'address': 'Hotel Djang Djaya 2, Jalan Syarifuddin Yoes, Balikpapan 76114, East Kalimantan, Indonesia',
#   'name': 'Hotel Djang Djaya 2',
#   'distance': 1004},
#  {'city': 'Pailón',
#   'country': 'BO',
#   'latitude': -17.65,
#   'longitude': -62.75,
#   'address': 'RN4: Pailon-Paraiso, Municipio Pailón, Bolivia',
#   'name': None,
#   'distance': 8584},
#  {'city': 'Inhuma',
#   'country': 'BR',
#   'latitude': -6.6683,
#   'longitude': -41.7078,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Mehrabpur',
#   'country': 'PK',
#   'latitude': 28.1085,
#   'longitude': 68.0254,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Richards Bay',
#   'country': 'ZA',
#   'latitude': -28.783,
#   'longitude': 32.0377,
#   'address': 'SUN1 Richards Bay, 6 South East Central, Veldenvlei, Richards Bay, 3900, South Africa',
#   'name': 'SUN1 Richards Bay',
#   'distance': 3814},
#  {'city': 'Hadibu',
#   'country': 'YE',
#   'latitude': 12.65,
#   'longitude': 54.0333,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Parkes',
#   'country': 'AU',
#   'latitude': -33.1333,
#   'longitude': 148.1833,
#   'address': 'Commercial Hotel, 161-163 Clarinda Street, Parkes NSW 2870, Australia',
#   'name': 'Commercial Hotel',
#   'distance': 926},
#  {'city': 'Chimoré',
#   'country': 'BO',
#   'latitude': -16.9833,
#   'longitude': -65.1333,
#   'address': 'Aquí me quedo, RN4: Villa Tunari-Ivirgarzama, Municipio Chimore, Bolivia',
#   'name': 'Aquí me quedo',
#   'distance': 5684},
#  {'city': 'Ulladulla',
#   'country': 'AU',
#   'latitude': -35.35,
#   'longitude': 150.4667,
#   'address': 'Hotel Marlin, Princes Highway, Ulladulla NSW 2539, Australia',
#   'name': 'Hotel Marlin',
#   'distance': 1177},
#  {'city': 'Ciudad de Huajuapan de León',
#   'country': 'MX',
#   'latitude': 17.8,
#   'longitude': -97.7667,
#   'address': 'Casa Blanca, Avenida Paraísos, 69000 Huajuapan, OAX, Mexico',
#   'name': 'Casa Blanca',
#   'distance': 1054},
#  {'city': 'Lagos',
#   'country': 'NG',
#   'latitude': 6.5833,
#   'longitude': 3.75,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Rābigh',
#   'country': 'SA',
#   'latitude': 22.7986,
#   'longitude': 39.0349,
#   'address': 'S.A. TALKE Villa, King Abdullah Bin Abdulaziz Road, Rabigh, Saudi Arabia',
#   'name': 'S.A. TALKE Villa',
#   'distance': 2019},
#  {'city': 'Coração de Jesus',
#   'country': 'BR',
#   'latitude': -16.6853,
#   'longitude': -44.365,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Phan Rang-Thap Cham',
#   'country': 'VN',
#   'latitude': 11.5667,
#   'longitude': 108.9833,
#   'address': 'Khách Sạn Ninh Thuận, Hai Mươi Mốt Tháng Tám, Phường Mỹ Hương, Phan Rang–Tháp Chàm, Ninh Thuận Province, Vietnam',
#   'name': 'Khách Sạn Ninh Thuận',
#   'distance': 739},
#  {'city': 'Saint-Joseph',
#   'country': 'RE',
#   'latitude': -21.3667,
#   'longitude': 55.6167,
#   'address': 'PALM Hotel & Spa, 43 Rue des Mascarins, 97429 Petite-Île, France',
#   'name': 'PALM Hotel & Spa',
#   'distance': 6836},
#  {'city': 'Arawa',
#   'country': 'PG',
#   'latitude': -6.2132,
#   'longitude': 155.5367,
#   'address': 'Bovotel, Arawa, Autonomous Region of Bougainville, Papua New Guinea',
#   'name': 'Bovotel',
#   'distance': 3500},
#  {'city': 'Tweed Heads',
#   'country': 'AU',
#   'latitude': -28.1817,
#   'longitude': 153.547,
#   'address': 'Dolphins Harbourside Hotel, 17-21 Wharf Street, Tweed Heads NSW 2485, Australia',
#   'name': 'Dolphins Harbourside Hotel',
#   'distance': 1318},
#  {'city': 'Muntok',
#   'country': 'ID',
#   'latitude': -2.0667,
#   'longitude': 105.1833,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Perbaungan',
#   'country': 'ID',
#   'latitude': 3.5679,
#   'longitude': 98.956,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Daru',
#   'country': 'PG',
#   'latitude': -9.0763,
#   'longitude': 143.2092,
#   'address': 'Kuki, Murray (Mangopari) Road, Daru Western, Papua New Guinea',
#   'name': 'Kuki',
#   'distance': 399},
#  {'city': 'Kroya',
#   'country': 'ID',
#   'latitude': -7.6331,
#   'longitude': 109.2461,
#   'address': 'Setia Hotel, Stasiun, Kroya 53282, Central Java, Indonesia',
#   'name': 'Setia Hotel',
#   'distance': 763},
#  {'city': 'Port Hedland',
#   'country': 'AU',
#   'latitude': -20.3167,
#   'longitude': 118.5667,
#   'address': 'The Esplanade Hotel, The Esplanade, Port Hedland WA 6721, Australia',
#   'name': 'The Esplanade Hotel',
#   'distance': 1021},
#  {'city': 'Nyaunglebin',
#   'country': 'MM',
#   'latitude': 17.95,
#   'longitude': 96.7333,
#   'address': 'စန်းဋ္ဌေး, 1, Nyaunglebin Township, 08031, Myanmar',
#   'name': 'စန်းဋ္ဌေး',
#   'distance': 1113},
#  {'city': 'Kani Keli',
#   'country': 'YT',
#   'latitude': -12.9536,
#   'longitude': 45.1033,
#   'address': 'Hôtel Le Jardin Maoré, D 4, 97625 Kani-Kéli, France',
#   'name': 'Hôtel Le Jardin Maoré',
#   'distance': 2171},
#  {'city': 'Obo',
#   'country': 'CF',
#   'latitude': 5.3998,
#   'longitude': 26.4869,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Kontcha',
#   'country': 'CM',
#   'latitude': 7.9667,
#   'longitude': 12.2333,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Kodīnar',
#   'country': 'IN',
#   'latitude': 20.7903,
#   'longitude': 70.7031,
#   'address': 'Hotel, SH6, Kodinar - 362715, Gujarat, India',
#   'name': 'Hotel',
#   'distance': 1174},
#  {'city': 'Ocosingo',
#   'country': 'MX',
#   'latitude': 17.0667,
#   'longitude': -92.25,
#   'address': 'Chilum Banak Chawuk, Avenida Ubilio García, Chilón, CHP, Mexico',
#   'name': 'Chilum Banak Chawuk',
#   'distance': 4140},
#  {'city': 'Umm Hājar',
#   'country': 'TD',
#   'latitude': 13.2954,
#   'longitude': 19.6966,
#   'address': None,
#   'name': None,
#   'distance': None},
#  {'city': 'Karwar',
#   'country': 'IN',
#   'latitude': 14.8,
#   'longitude': 74.1333,
#   'address': 'Emerald Bay, Karwar, Sterling Holidays, NH66, Chittakula - 581352, Karnataka, India',
#   'name': 'Emerald Bay, Karwar, Sterling Holidays',
#   'distance': 5337},
#  {'city': 'Mbanza Kongo',
#   'country': 'AO',
#   'latitude': -6.267,
#   'longitude': 14.2401,
#   'address': "Hotel Estrela de Congo, EN120, M'banza Congo, Angola",
#   'name': 'Hotel Estrela de Congo',
#   'distance': 758},
#  {'city': 'Séguéla',
#   'country': 'CI',
#   'latitude': 7.9611,
#   'longitude': -6.6731,
#   'address': "Hôtel Carrefour, Séguéla - Boundiali, Séguéla, Côte d'Ivoire",
#   'name': 'Hôtel Carrefour',
#   'distance': 525},
#  {'city': 'Manokwari',
#   'country': 'ID',
#   'latitude': -0.8667,
#   'longitude': 134.0833,
#   'address': 'Hotel Arfak, Jalan Brawijaya, Manokwari 98311, West Papua, Indonesia',
#   'name': 'Hotel Arfak',
#   'distance': 645},
#  {'city': 'Gorontalo',
#   'country': 'ID',
#   'latitude': 0.5412,
#   'longitude': 123.0595,
#   'address': 'Hotel Karawang Gorontalo, Jalan Nani Wartabone, Gorontalo 96114, Gorontalo, Indonesia',
#   'name': 'Hotel Karawang Gorontalo',
#   'distance': 153},
#  {'city': 'Capitán Bado',
#   'country': 'PY',
#   'latitude': -23.2667,
#   'longitude': -55.5333,
#   'address': 'Hotel Esmeralda, Avenida Internacional, Capitán Bado, Paraguay',
#   'name': 'Hotel Esmeralda',
#   'distance': 797},
#  {'city': 'Biltine',
#   'country': 'TD',
#   'latitude': 14.5333,
#   'longitude': 20.9167,
#   'address': 'فندق ثلاث نجوم بلتن, Abeche - Biltine National Road, Biltine, Chad',
#   'name': 'فندق ثلاث نجوم بلتن',
#   'distance': 612},
#  {'city': 'Ribeirão Bonito',
#   'country': 'BR',
#   'latitude': -22.0667,
#   'longitude': -48.1761,
#   'address': 'Hotel Santa Eliza, Rodovia Luiz Augusto de Oliveira, Ribeirão Bonito - SP, Brazil',
#   'name': 'Hotel Santa Eliza',
#   'distance': 6955}]

# %%
hotel_df = pd.DataFrame(hotel_rows)
hotel_df
# Out:
#                  city country  latitude  longitude  \
# 0              Kourou      GF    5.1552   -52.6478
# 1   Wailua Homesteads      US   22.0669  -159.3780
# 2               Dawei      MM   14.0833    98.2000
# 3             Jwaneng      BW  -24.6004    24.7303
# 4      Cabo San Lucas      MX   22.8909  -109.9124
# ..                ...     ...       ...        ...
# 88          Manokwari      ID   -0.8667   134.0833
# 89          Gorontalo      ID    0.5412   123.0595
# 90       Capitán Bado      PY  -23.2667   -55.5333
# 91            Biltine      TD   14.5333    20.9167
# 92    Ribeirão Bonito      BR  -22.0667   -48.1761
#
#                                               address  \
# 0   SCI Horizon, 54 Rue du Docteur Hervé Floch, 97...
# 1   Hilton Garden Inn Kauai Wailua Bay, Kuhio High...
# 2   Royal Dawei Hotel, Say Yone Road, Dawei, 60101...
# 3   Mokala Lodge & Teemane Casino, Kgorwe Avenue, ...
# 4   Comfort Rooms, Calle Revolución de 1910, Juáre...
# ..                                                ...
# 88  Hotel Arfak, Jalan Brawijaya, Manokwari 98311,...
# 89  Hotel Karawang Gorontalo, Jalan Nani Wartabone...
# 90  Hotel Esmeralda, Avenida Internacional, Capitá...
# 91  فندق ثلاث نجوم بلتن, Abeche - Biltine National...
# 92  Hotel Santa Eliza, Rodovia Luiz Augusto de Oli...
#
#                                   name  distance
# 0                          SCI Horizon     299.0
# 1   Hilton Garden Inn Kauai Wailua Bay    4923.0
# 2                   Royal Dawei ဟိုတယ်     784.0
# 3        Mokala Lodge & Teemane Casino     187.0
# 4                        Comfort Rooms      65.0
# ..                                 ...       ...
# 88                         Hotel Arfak     645.0
# 89            Hotel Karawang Gorontalo     153.0
# 90                     Hotel Esmeralda     797.0
# 91                 فندق ثلاث نجوم بلتن     612.0
# 92                   Hotel Santa Eliza    6955.0
#
# [93 rows x 7 columns]

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

# Use the Pandas copy function to create a new DataFrame called hotel_df
hotel_df = ideal_w[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                  City Country      Lat       Lng  Humidity Hotel Name
# 0              Kourou      GF   5.1552  -52.6478        92
# 1   Wailua Homesteads      US  22.0669 -159.3780        80
# 2               Dawei      MM  14.0833   98.2000        79
# 3             Jwaneng      BW -24.6004   24.7303        18
# 4      Cabo San Lucas      MX  22.8909 -109.9124        61
# ..                ...     ...      ...       ...       ...        ...
# 88          Manokwari      ID  -0.8667  134.0833        84
# 89          Gorontalo      ID   0.5412  123.0595        90
# 90       Capitán Bado      PY -23.2667  -55.5333        84
# 91            Biltine      TD  14.5333   20.9167        15
# 92    Ribeirão Bonito      BR -22.0667  -48.1761        86
#
# [93 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Kourou - nearest hotel: Hotel Santa Eliza
# Wailua Homesteads - nearest hotel: Hotel Santa Eliza
# Dawei - nearest hotel: Hotel Santa Eliza
# Jwaneng - nearest hotel: Hotel Santa Eliza
# Cabo San Lucas - nearest hotel: Hotel Santa Eliza
# Nieuw Amsterdam - nearest hotel: Hotel Santa Eliza
# Owando - nearest hotel: Hotel Santa Eliza
# Koné - nearest hotel: Hotel Santa Eliza
# Sinabang - nearest hotel: Hotel Santa Eliza
# Gordonvale - nearest hotel: Hotel Santa Eliza
# Al Muwayh - nearest hotel: Hotel Santa Eliza
# Boyolangu - nearest hotel: Hotel Santa Eliza
# Tabou - nearest hotel: Hotel Santa Eliza
# Kapaa - nearest hotel: Hotel Santa Eliza
# Yangon - nearest hotel: Hotel Santa Eliza
# Marabu - nearest hotel: Hotel Santa Eliza
# Simanggang - nearest hotel: Hotel Santa Eliza
# Toliara - nearest hotel: Hotel Santa Eliza
# Pisco - nearest hotel: Hotel Santa Eliza
# Haiku-Pauwela - nearest hotel: Hotel Santa Eliza
# Angoche - nearest hotel: Hotel Santa Eliza
# Alice Springs - nearest hotel: Hotel Santa Eliza
# Avarua - nearest hotel: Hotel Santa Eliza
# Quelimane - nearest hotel: Hotel Santa Eliza
# Kabo - nearest hotel: Hotel Santa Eliza
# Port Moresby - nearest hotel: Hotel Santa Eliza
# Acapulco de Juárez - nearest hotel: Hotel Santa Eliza
# Bougouni - nearest hotel: Hotel Santa Eliza
# Jayapura - nearest hotel: Hotel Santa Eliza
# Tibati - nearest hotel: Hotel Santa Eliza
# Tobelo - nearest hotel: Hotel Santa Eliza
# Nadi - nearest hotel: Hotel Santa Eliza
# Sumbawa Besar - nearest hotel: Hotel Santa Eliza
# Banda Aceh - nearest hotel: Hotel Santa Eliza
# Nelson Bay - nearest hotel: Hotel Santa Eliza
# Chimoio - nearest hotel: Hotel Santa Eliza
# Guerrero Negro - nearest hotel: Hotel Santa Eliza
# Wewak - nearest hotel: Hotel Santa Eliza
# Dubai - nearest hotel: Hotel Santa Eliza
# Petauke - nearest hotel: Hotel Santa Eliza
# Goundam - nearest hotel: Hotel Santa Eliza
# Las Lomitas - nearest hotel: Hotel Santa Eliza
# Alotau - nearest hotel: Hotel Santa Eliza
# Moranbah - nearest hotel: Hotel Santa Eliza
# Sittwe - nearest hotel: Hotel Santa Eliza
# Rancho Palos Verdes - nearest hotel: Hotel Santa Eliza
# Wau - nearest hotel: Hotel Santa Eliza
# Auki - nearest hotel: Hotel Santa Eliza
# Luanda - nearest hotel: Hotel Santa Eliza
# Cepu - nearest hotel: Hotel Santa Eliza
# Meulaboh - nearest hotel: Hotel Santa Eliza
# Song Cau - nearest hotel: Hotel Santa Eliza
# Al Ghayzah - nearest hotel: Hotel Santa Eliza
# Sawa Sawa - nearest hotel: Hotel Santa Eliza
# Kaga-Bandoro - nearest hotel: Hotel Santa Eliza
# Pandan - nearest hotel: Hotel Santa Eliza
# City of Balikpapan - nearest hotel: Hotel Santa Eliza
# Pailón - nearest hotel: Hotel Santa Eliza
# Inhuma - nearest hotel: Hotel Santa Eliza
# Mehrabpur - nearest hotel: Hotel Santa Eliza
# Richards Bay - nearest hotel: Hotel Santa Eliza
# Hadibu - nearest hotel: Hotel Santa Eliza
# Parkes - nearest hotel: Hotel Santa Eliza
# Chimoré - nearest hotel: Hotel Santa Eliza
# Ulladulla - nearest hotel: Hotel Santa Eliza
# Ciudad de Huajuapan de León - nearest hotel: Hotel Santa Eliza
# Lagos - nearest hotel: Hotel Santa Eliza
# Rābigh - nearest hotel: Hotel Santa Eliza
# Coração de Jesus - nearest hotel: Hotel Santa Eliza
# Phan Rang-Thap Cham - nearest hotel: Hotel Santa Eliza
# Saint-Joseph - nearest hotel: Hotel Santa Eliza
# Arawa - nearest hotel: Hotel Santa Eliza
# Tweed Heads - nearest hotel: Hotel Santa Eliza
# Muntok - nearest hotel: Hotel Santa Eliza
# Perbaungan - nearest hotel: Hotel Santa Eliza
# Daru - nearest hotel: Hotel Santa Eliza
# Kroya - nearest hotel: Hotel Santa Eliza
# Port Hedland - nearest hotel: Hotel Santa Eliza
# Nyaunglebin - nearest hotel: Hotel Santa Eliza
# Kani Keli - nearest hotel: Hotel Santa Eliza
# Obo - nearest hotel: Hotel Santa Eliza
# Kontcha - nearest hotel: Hotel Santa Eliza
# Kodīnar - nearest hotel: Hotel Santa Eliza
# Ocosingo - nearest hotel: Hotel Santa Eliza
# Umm Hājar - nearest hotel: Hotel Santa Eliza
# Karwar - nearest hotel: Hotel Santa Eliza
# Mbanza Kongo - nearest hotel: Hotel Santa Eliza
# Séguéla - nearest hotel: Hotel Santa Eliza
# Manokwari - nearest hotel: Hotel Santa Eliza
# Gorontalo - nearest hotel: Hotel Santa Eliza
# Capitán Bado - nearest hotel: Hotel Santa Eliza
# Biltine - nearest hotel: Hotel Santa Eliza
# Ribeirão Bonito - nearest hotel: Hotel Santa Eliza
#                  City Country      Lat       Lng  Humidity         Hotel Name
# 0              Kourou      GF   5.1552  -52.6478        92  Hotel Santa Eliza
# 1   Wailua Homesteads      US  22.0669 -159.3780        80  Hotel Santa Eliza
# 2               Dawei      MM  14.0833   98.2000        79  Hotel Santa Eliza
# 3             Jwaneng      BW -24.6004   24.7303        18  Hotel Santa Eliza
# 4      Cabo San Lucas      MX  22.8909 -109.9124        61  Hotel Santa Eliza
# ..                ...     ...      ...       ...       ...                ...
# 88          Manokwari      ID  -0.8667  134.0833        84  Hotel Santa Eliza
# 89          Gorontalo      ID   0.5412  123.0595        90  Hotel Santa Eliza
# 90       Capitán Bado      PY -23.2667  -55.5333        84  Hotel Santa Eliza
# 91            Biltine      TD  14.5333   20.9167        15  Hotel Santa Eliza
# 92    Ribeirão Bonito      BR -22.0667  -48.1761        86  Hotel Santa Eliza
#
# [93 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    c="Hotel Name",
    color = "City",  
    colorbar=True,
    size=20,
    hover_cols=["Hotel Name", "City", "Country"]
)

# Display the map plot
hotel_map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
